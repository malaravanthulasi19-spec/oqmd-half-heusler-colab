# %% [markdown]
# # Run literature review staged batches

# %%
import os
from getpass import getpass
if not os.getenv('SERPAPI_API_KEY'):
    os.environ['SERPAPI_API_KEY'] = getpass('Enter SERPAPI_API_KEY: ')

from literature_review.pipeline import run
for n in [10, 25, 100, 250]:
    print('Running top_n=', n)
    print(run(top_n=n))
print('Run full 3117 only after quality confirmation.')
